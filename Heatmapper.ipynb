# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !jupyter nbextension enable --py --sys-prefix gmaps
import gmaps
import pandas as pd
from config import gkey
# Google developer API key


# Configure gmaps
gmaps.configure(api_key=gkey)
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
# Create aiport dataframe
accidentmapdf = pd.read_json('Resources/CleanedData.json')
accidentmapdf.dropna()
accidentmapdf.head()
# Out:
#                        ID Criticality   Latitude   Longitude  \
# 0      100372617581716855       minor  33.162394  -87.549211
# 1     4320793649494536642    critical  32.754060  -86.511290
# 10     433454766143288697       minor  33.386590 -111.748610
# 100    483322249055962197       minor  33.928085 -118.340919
# 1000   176787206817732943       minor  33.856856 -118.028743
#
#               Start_time            End_time  Duration_(seconds)  \
# 0    2019-10-02 03:55:07 2019-10-02 04:25:05                1798
# 1    2019-10-03 18:00:28 2019-10-03 18:30:02                1774
# 10   2019-10-01 13:35:15 2019-10-01 14:03:18                1683
# 100  2019-10-01 12:47:00 2019-10-01 14:22:59                5759
# 1000 2019-10-03 11:32:00 2019-10-03 12:04:01                1921
#
#       Vehicle_response  Road_closure
# 0                False         False
# 1                False          True
# 10               False         False
# 100              False         False
# ...

# %%
# Store latitude and longitude in locations
locations = accidentmapdf[["Latitude", "Longitude"]]
locations
# Out:
#        Latitude   Longitude
# 0     33.162394  -87.549211
# 1     32.754060  -86.511290
# 10    33.386590 -111.748610
# 100   33.928085 -118.340919
# 1000  33.856856 -118.028743
# 1001  34.173478 -118.553463
# 1002  34.061165 -118.247580
# 1003  34.068110 -118.028740
# 1004  33.996283 -117.888308
# 1005  33.980598 -117.340263
# 1006  34.082482 -118.073305
# 1007  33.856750 -117.978786
# 1008  33.648877 -117.733688
# 1009  34.042991 -118.220972
# 101   34.117697 -117.846330
# 1010  34.505836 -118.114590
# 1011  33.928979 -118.230317
# 1012  34.063839 -117.811951
# 1013  34.068718 -117.839487
# 1014  34.119821 -117.838627
# 1015  34.136540 -117.523521
# 1016  33.916392 -118.361274
# 1017  34.065284 -117.806665
# 1018  33.961684 -118.369290
# 1019  33.872420 -117.665130
# 102   33.957241 -118.062366
# 1020  34.063802 -118.159435
# 1021  34.135921 -117.399917
# 1022  34.060325 -118.169708
# 1023  34.426715 -117.380183
# ...         ...         ...
# 972   34.233558 -118.472957
# ...

# %%
# Plot Heatmap
fig =gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, 
                                 dissipating=False, max_intensity=3,
                                 point_radius=.05)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot Heatmap
fig2 = gmaps.figure()

# Create heat layer
heat_layer2 = gmaps.symbol_layer(
    locations, fill_color='green', stroke_color='green', scale=1
)


# Add layer
fig2.add_layer(heat_layer2)

# Display figure
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))
